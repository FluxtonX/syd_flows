# %%
import shutil
import os

files_to_copy = {
    '/Users/mc/.gemini/antigravity-ide/brain/62db993c-8450-423c-81a1-5d4c029f0081/syd_flow_logo_1782957217537.png': '/Users/mc/projects/syd_flow/assets/images/logo.png',
    '/Users/mc/.gemini/antigravity-ide/brain/62db993c-8450-423c-81a1-5d4c029f0081/onboarding_workout_1782957534724.png': '/Users/mc/projects/syd_flow/assets/images/onboarding/onboarding_1.png',
    '/Users/mc/.gemini/antigravity-ide/brain/62db993c-8450-423c-81a1-5d4c029f0081/onboarding_track_1782957561624.png': '/Users/mc/projects/syd_flow/assets/images/onboarding/onboarding_2.png',
    '/Users/mc/.gemini/antigravity-ide/brain/62db993c-8450-423c-81a1-5d4c029f0081/onboarding_recommend_1782957591341.png': '/Users/mc/projects/syd_flow/assets/images/onboarding/onboarding_3.png',
    '/Users/mc/.gemini/antigravity-ide/brain/62db993c-8450-423c-81a1-5d4c029f0081/onboarding_progress_1782957622119.png': '/Users/mc/projects/syd_flow/assets/images/onboarding/onboarding_4.png',
    '/Users/mc/.gemini/antigravity-ide/brain/62db993c-8450-423c-81a1-5d4c029f0081/onboarding_private_1782957656390.png': '/Users/mc/projects/syd_flow/assets/images/onboarding/onboarding_5.png',
}

for src, dest in files_to_copy.items():
    dest_dir = os.path.dirname(dest)
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)
    try:
        shutil.copy(src, dest)
        print(f"Copied {os.path.basename(src)} -> {os.path.basename(dest)}")
    except Exception as e:
        print(f"Error copying {os.path.basename(src)}: {e}")
